# %%
import re
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %%
url1='https://www.skinnytaste.com/recipe-index/?_course=lunch'
page=requests.get(url1)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)
#soup

# %%
main=soup.find_all('span',class_='wprm-total-time')
#main

# %%
URL=['https://www.skinnytaste.com/recipe-index/?_course=lunch']
for i in range(2,11):
    URL.append(URL[0]+'&_paged='+str(i))
    
    
URL
# Out:
# ['https://www.skinnytaste.com/recipe-index/?_course=lunch',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=2',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=3',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=4',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=5',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=6',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=7',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=8',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=9',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=10']

# %% [markdown]
# ## Time- column

# %%
time=[]
for i in main:
    time.append(i.text)
time
# Out:
# ['20 mins',
#  '25 mins',
#  '55 mins',
#  '1 hr 15 mins',
#  '20 mins',
#  '15 mins',
#  '15 mins',
#  '1 hr',
#  '45 mins',
#  '55 mins',
#  '21 mins',
#  '15 mins',
#  '30 mins',
#  '10 mins',
#  '10 mins',
#  '40 mins',
#  '4 hrs 5 mins',
#  '29 mins',
#  '45 mins',
#  '30 mins']

# %%
# a=re.findall('href=\"(.+)"><img',str(url[0]))
# a[0].split(' ')[0].split('"')[0]

# %%
#links
url=soup.find_all('div',class_='post-thumb-img-content post-thumb')
sub_url=[]
for i in url:
    a=re.findall('href=\"(.+)"><img',str(i))
    sub_url.append(a[0].split(' ')[0].split('"')[0])
len(sub_url)
# Out:
# 20

# %% [raw]
# # converting above urls(html) into string data
#
# for i in sub_url:
#     page=requests.get(i)
#     soup = BeautifulSoup(page.text)
#
# soup.text

# %% [raw]
# for i in sub_url:
#     page=requests.get(i)
#     soup = BeautifulSoup(page.text)
#     urls=[]
#     single=[]
#     for j in soup.find_all('a'):
#         single.append(j.text)
#         urls.append(single)
# urls

# %%
# urls=[]
# single=[]
# for j in soup.find_all('a'):
#     single.append(j.text)

#     urls.append(single)
# single
# urls[0]

# %%
link='https://www.skinnytaste.com/italian-sub-salad/'
page=requests.get(link)
soup = BeautifulSoup(page.text)
#soup

# %%
#title
soup.find_all('h1')[0].text

# %%
#rating
soup.find_all('span',class_='wprm-recipe-rating-average')[0].text

# %%
#calories
c=soup.find_all('span',class_='recipe-meta-value value-calories')[0].text
c.split(' ')[1]

# %%
#protein
p=soup.find_all('span',class_='recipe-meta-value value-protein')[0].text
p.split(' ')[1]

# %%
#carbs
c=soup.find_all('span',class_='recipe-meta-value value-carbs')[0].text
c.split(' ')[1]

# %%
#fats
f=soup.find_all('span',class_='recipe-meta-value value-fat')[0].text
f.split(' ')[1]

# %%
#serving
s=soup.find_all('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
s[0].text

# %%
#type
t=soup.find_all('a',class_= 'wprm-recipe-course wprm-block-text-normal')
t[0].text

# %%
#ingredients
# ii=soup.find_all('strong')
# re.findall('\>(\w+)',str(ii))

# %%
URL
# Out:
# ['https://www.skinnytaste.com/recipe-index/?_course=lunch',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=2',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=3',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=4',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=5',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=6',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=7',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=8',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=9',
#  'https://www.skinnytaste.com/recipe-index/?_course=lunch&_paged=10']

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=lunch']
Time = []
sub_url = []

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)
    print(page)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
print(len(Time))  
print(len(sub_url))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# 200
# 200

# %%
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]
cholesterol=[]
sodium=[]
fiber=[]
sugar=[]
pre_time=[]
cook_time=[]
    
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find('h1').text)
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)
    
    c=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-cholesterol')
    cholesterol.append(c.text.split(' ')[1] if c else np.nan)
    
    sod=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sodium')
    sodium.append(sod.text.split()[1] if sod else np.nan)
    
    f=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-fiber')
    fiber.append(f.text.split()[1] if f else np.nan)
    
    ss=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sugar')
    sugar.append(ss.text.split()[1] if ss else np.nan)
    
    pt=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-prep_time wprm-recipe-prep_time-minutes')
    pre_time.append(pt.text.split()[0] if pt else np.nan)
    
    ct=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes')
    cook_time.append(ct.text.split()[0] if ct else np.nan)
    
    
    
print(len(Title))
print(len(rating))
print(len(protein))
print(len(calories))
print(len(carbs))
print(len(fat))
print(len(serving))
print(len(type_of))
print(len(cholesterol))
print(len(sodium))
print(len(fiber))
print(len(sugar))
print(len(pre_time))
print(len(cook_time))
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
cook_time
# Out:
# ['0',
#  '15',
#  '40',
#  nan,
#  '15',
#  '0',
#  '0',
#  '40',
#  '35',
#  '45',
#  '6',
#  '10',
#  '20',
#  '10',
#  nan,
#  '30',
#  nan,
#  '24',
#  '30',
#  '10',
#  '20',
#  '16',
#  '10',
#  '8',
#  nan,
#  '24',
#  '35',
#  '35',
#  '20',
#  '12',
#  '20',
#  '10',
#  '10',
#  '15',
#  nan,
#  '15',
#  '12',
#  '15',
#  '0',
#  '30',
#  '10',
#  '40',
#  '10',
#  '0',
#  '2',
#  '55',
#  '0',
#  '3',
#  '25',
#  '10',
#  '30',
#  '5',
#  '10',
#  '15',
#  '15',
#  '5',
#  '25',
#  '30',
#  nan,
#  '45',
#  '10',
#  '30',
#  '6',
#  '15',
#  '15',
#  '15',
#  '10',
#  '35',
#  '15',
#  '40',
#  '25',
#  '20',
#  nan,
#  '7',
#  '0',
#  '30',
#  '10',
#  '15',
#  '45',
#  '15',
#  '10',
#  '10',
#  '20',
#  nan,
#  '0',
#  '10',
#  '20',
#  '10',
#  '10',
#  '10',
#  '10',
#  '0',
#  '0',
#  '10',
#  '0',
#  '10',
#  '20',
#  nan,
#  '10',
#  '5',
#  '0',
#  '15',
#  nan,
#  nan,
#  '0',
#  '20',
#  '5',
#  '16',
#  '15',
#  '10',
#  '20',
#  '40',
#  '20',
#  '50',
#  '30',
#  '25',
#  '16',
#  '30',
#  '15',
#  '30',
#  '20',
#  '30',
#  '5',
#  '0',
#  '10',
#  '30',
#  '15',
#  '15',
#  '20',
#  '15',
#  '15',
#  '50',
#  nan,
#  '15',
#  '10',
#  '0',
#  '40',
#  '10',
#  '15',
#  '30',
#  '0',
#  '15',
#  '15',
#  '15',
#  '18',
#  '20',
#  '45',
#  '15',
#  '20',
#  '20',
#  '20',
#  '10',
#  '20',
#  '40',
#  '0',
#  '0',
#  '35',
#  '10',
#  '35',
#  '25',
#  '50',
#  '10',
#  '15',
#  '20',
#  '15',
#  '10',
#  '10',
#  '15',
#  '25',
#  '40',
#  '30',
#  '5',
#  '0',
#  '25',
#  '20',
#  '20',
#  '15',
#  '50',
#  '0',
#  nan,
#  nan,
#  '10',
#  '30',
#  '25',
#  '25',
#  nan,
#  '15',
#  '35',
#  '30',
#  '20',
#  '35',
#  '10',
#  '10',
#  '15',
#  '30',
#  '10',
#  '15',
#  '8',
#  '5',
#  nan]

# %%
df2=pd.DataFrame({'Recipe_Name':Title,
                  "Type":type_of,
                  'Serving':serving,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'cholesterol':cholesterol,
                  'sodium':sodium,
                  'fiber':fiber,
                  'sugar':sugar,
                    'Prepare time':pre_time,
                  'cooking time': cook_time,
                  "Total_Time":Time,
                  "Ratings":rating,

                 
                 
                 })
df2.tail(3)
# Out:
#                               Recipe_Name    Type Serving Protein   Fat Carbs  \
# 197                           Turkey Club   lunch       1      35  11.5  28.5
# 198  Open-Faced Tuna Melt Sandwich Recipe   Lunch       1    28.5   6.5  14.5
# 199                  Paprika Chicken Stew  Dinner       1      49    11    14
#
#     Calories cholesterol sodium fiber sugar Prepare time cooking time  \
# 197      351          65  652.5   6.5   4.5            2            8
# 198      231         NaN    NaN   3.5   NaN            5            5
# 199      361         214    954     3     4           15          NaN
#
#        Total_Time Ratings
# 197       10 mins       5
# 198       10 mins    4.75
# 199  1 hr 15 mins    4.58

# %%
#df2.to_csv("lunch.csv")
df2=pd.read_csv('lunch.csv')
df2
# Out:
#      Unnamed: 0                           Recipe_Name       Type  Serving  \
# 0             0                     Italian Sub Salad     Dinner      2.0
# 1             1                          Deviled Eggs  appetizer      2.0
# 2             2                      Crustless Quiche     dinner      1.0
# 3             3  Spanish Tortilla with Pimenton Aioli  appetizer      1.0
# 4             4                            Fish Cakes     Dinner      2.0
# ..          ...                                   ...        ...      ...
# 195         195        Omelet Tortilla Breakfast Wrap  Breakfast      1.0
# 196         196                      Margherita Pizza  Appetizer      2.0
# 197         197                           Turkey Club      lunch      1.0
# 198         198  Open-Faced Tuna Melt Sandwich Recipe      Lunch      1.0
# 199         199                  Paprika Chicken Stew     Dinner      1.0
#
#      Protein   Fat  Carbs  Calories  cholesterol  sodium  fiber  sugar  \
# 0       22.0  19.0   11.5     298.0         71.5  1573.5    3.0    5.5
# 1        6.3   7.5    1.0      96.8        187.0   156.1    NaN    0.3
# 2       20.0  12.5    5.0     215.0        193.0   620.0    1.0    2.5
# 3        9.0  14.5   21.5     247.0        188.0   363.5    2.0    2.5
# 4       29.0   9.5   19.5     277.0        153.5   624.0    1.0    3.0
# ..       ...   ...    ...       ...          ...     ...    ...    ...
# 195     28.0  17.0   23.0     315.0        377.0  1037.0   14.5    2.0
# 196     15.0   6.5   27.0     236.0         23.5   636.0    1.0    3.5
# 197     35.0  11.5   28.5     351.0         65.0   652.5    6.5    4.5
# 198     28.5   6.5   14.5     231.0          NaN     NaN    3.5    NaN
# 199     49.0  11.0   14.0     361.0        214.0   954.0    3.0    4.0
#
#      Prepare time  cooking time    Total_Time  Ratings
# 0            20.0           0.0       20 mins     5.00
# 1            10.0          15.0       25 mins     4.78
# 2            15.0          40.0       55 mins     4.88
# 3            15.0           NaN  1 hr 15 mins     4.44
# 4             5.0          15.0       20 mins     4.84
# ..            ...           ...           ...      ...
# 195           5.0          10.0       15 mins     4.93
# 196          30.0          15.0       45 mins     4.84
# 197           2.0           8.0       10 mins     5.00
# 198           5.0           5.0       10 mins     4.75
# 199          15.0           NaN  1 hr 15 mins     4.58
#
# [200 rows x 16 columns]

# %%
df2['Type'].unique()
# Out:
# array(['Dinner', 'appetizer', 'dinner', 'lunch', 'Rice Bowl', 'breakfast',
#        'Instant Pot', 'cauliflower rice', 'burger',
#        'boneless chicken thighs', 'Cottage Cheese', 'Appetizer',
#        'dessert', 'Lettuce Wraps', 'rice bowl', 'Quinoa', 'Breakfast',
#        'quinoa', 'Lunch', nan, 'lettuce wraps', 'Asparagus',
#        'canned tuna', 'cottage cheese', 'Burger'], dtype=object)
