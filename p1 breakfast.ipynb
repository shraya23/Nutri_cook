# %%
import re
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %%
URL=['https://www.skinnytaste.com/recipe-index/?_course=breakfast-brunch']
for i in range(2,11):
    URL.append(URL[0]+'&_paged='+str(i))#10pages
    
for j in URL:
    page=requests.get(j)
    soup=BeautifulSoup(page.text)
        
    print(page)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
URL

# %%
soup.find_all('span',class_='wprm-total-time')[0].text.split()[0]

# %%
main=soup.find_all('span',class_='wprm-total-time')
#main

# %% [markdown]
# ## Time- column

# %%
URL=['https://www.skinnytaste.com/recipe-index/?_course=breakfast-brunch']
time=[]
sub_url=[]
c=0

for i in range(2,11):
    URL.append(URL[0]+'&_paged='+str(i))#10pages
    
for j in URL:
    page=requests.get(j)
    soup=BeautifulSoup(page.text)
    
    for k in soup.find_all('span',class_='wprm-total-time'):
        time.append(k.text)
    
    for l in soup.find_all('div',class_='post-thumb-img-content post-thumb'):
        a=re.findall('href=\"(.+)"><img',str(l))        
        if a:
            sub_url.append(a[0].split(' ')[0].split('"')[0])
            
    
for sub in sub_url:
    page1=requests.get(sub)
    soup2 = BeautifulSoup(page1.text)
    c=c+1
print(len(time))#4 are missing
print(len(sub_url))
print(c)
# Out:
# 196
# 200
# 200

# %%
l=soup.find_all('div',class_='post-thumb-img-content post-thumb')[0]
m=re.findall('href=\"(.+)"><img',str(l))
m[0].split(' ')[0].split('"')[0]
# Out:
# 'https://www.skinnytaste.com/petite-crust-less-quiche/'

# %%
for l in url:
        a=re.findall('href=\"(.+)"><img',str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
len(sub_url)

# %%
#links
url=soup.find_all('div',class_='post-thumb-img-content post-thumb')
sub_url=[]
for i in url:
    a=re.findall('href=\"(.+)"><img',str(i))
    sub_url.append(a[0].split(' ')[0].split('"')[0])
sub_url

# %%
# converting above urls(html) into string data

for i in sub_url:
    page=requests.get(i)
    soup = BeautifulSoup(page.text)

#soup

# %%
for i in sub_url:
    page=requests.get(i)
    soup = BeautifulSoup(page.text)
    urls=[]
    single=[]
    for j in soup.find_all('a'):
        single.append(j.text)
        urls.append(single)
single

# %%
# urls=[]
# single=[]
# for j in soup.find_all('a'):
#     single.append(j.text)

#     urls.append(single)
# single
# urls[0]

# %%
link='https://www.skinnytaste.com/high-protein-oat-waffles/'
page=requests.get(link)
soup = BeautifulSoup(page.text)
#soup

# %%
#title
soup.find_all('h1')[0].text

# %%
#rating
soup.find_all('span',class_='wprm-recipe-rating-average')[0].text

# %%
#calories
c=soup.find_all('span',class_='recipe-meta-value value-calories')[0].text
c.split(' ')[1]

# %%
#protein
p=soup.find_all('span',class_='recipe-meta-value value-protein')[0].text
p.split(' ')[1]

# %%
#carbs
c=soup.find_all('span',class_='recipe-meta-value value-carbs')[0].text
c.split(' ')[1]

# %%
#fats
f=soup.find_all('span',class_='recipe-meta-value value-fat')[0].text
f.split(' ')[1]

# %%
#serving
s=soup.find_all('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
s[0].text

# %%
#type
t=soup.find_all('a',class_= 'tasty-link')
t[1].text

# %%
#ingredients
#ii=soup.find_all('strong')
#ii[8].text.split(">")[0].split(':')[0]

# %%
#ii

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=breakfast-brunch']
Time = []
sub_url = []

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
print(len(Time))  
print(len(sub_url))
# Out:
# 200
# 200

# %%
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]
cholesterol=[]
sodium=[]
fiber=[]
sugar=[]
pre_time=[]
cook_time=[]
    
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find('h1').text)
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)
    
    c=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-cholesterol')
    cholesterol.append(c.text.split(' ')[1] if c else np.nan)
    
    sod=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sodium')
    sodium.append(sod.text.split()[1] if sod else np.nan)
    
    f=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-fiber')
    fiber.append(f.text.split()[1] if f else np.nan)
    
    ss=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sugar')
    sugar.append(ss.text.split()[1] if ss else np.nan)
    
    pt=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-prep_time wprm-recipe-prep_time-minutes')
    pre_time.append(pt.text.split()[0] if pt else np.nan)
    
    ct=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes')
    cook_time.append(ct.text.split()[0] if ct else np.nan)
    
    
    
print(len(Title))
print(len(rating))
print(len(protein))
print(len(calories))
print(len(carbs))
print(len(fat))
print(len(serving))
print(len(type_of))
print(len(cholesterol))
print(len(sodium))
print(len(fiber))
print(len(sugar))
print(len(pre_time))
print(len(cook_time))
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
soup1.find_all('aside',class_='sidebar-border widget widget_recipe_key_widget')[0].text
# Out:
# 'Recipe KeyAir Fryer RecipesDairy FreeFreezer MealsGluten FreeKeto RecipesKid FriendlyLow CarbMeal Prep RecipesPaleoPressure Cooker RecipesSlow Cooker RecipesUnder 30 MinutesVegetarian MealsWhole30 Recipes'

# %%
soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-calories').text.split()[1]
# Out:
# '228'

# %%
# for i in soup.find_all('article', class_='ast-archive-post'):
#         time= i.find('span', class_='wprm-total-time')
         Time.append(time.text.strip() if time else np.nan)
# Out:
# []

# %%
Time
# Out:
# ['15 mins',
#  '25 mins',
#  '55 mins',
#  '1 hr 15 mins',
#  '25 mins',
#  '45 mins',
#  '35 mins',
#  '50 mins',
#  '5 mins',
#  '1 hr 20 mins',
#  '15 mins',
#  '27 mins',
#  '50 mins',
#  '45 mins',
#  '30 mins',
#  '1 hr 15 mins',
#  '45 mins',
#  '1 hr 10 mins',
#  '25 mins',
#  '40 mins',
#  '1 hr 10 mins',
#  '4 hrs 5 mins',
#  '45 mins',
#  '1 hr 13 mins',
#  '13 mins',
#  '1 hr 15 mins',
#  '30 mins',
#  '37 mins',
#  '15 mins',
#  '35 mins',
#  '15 mins',
#  nan,
#  '50 mins',
#  '7 mins',
#  '5 mins',
#  '1 hr 2 mins',
#  '1 hr 5 mins',
#  '1 hr 10 mins',
#  '2 hrs 10 mins',
#  '50 mins',
#  '7 mins',
#  '10 mins',
#  '1 hr',
#  '2 hrs 5 mins',
#  '55 mins',
#  '17 mins',
#  '17 mins',
#  '7 mins',
#  '8 hrs 25 mins',
#  '10 mins',
#  '1 hr 25 mins',
#  '20 mins',
#  '20 mins',
#  '40 mins',
#  '40 mins',
#  '8 hrs 10 mins',
#  '20 mins',
#  '17 mins',
#  '1 hr 30 mins',
#  '2 hrs 5 mins',
#  '15 mins',
#  '8 hrs 5 mins',
#  '5 hrs 5 mins',
#  '5 mins',
#  '1 hr',
#  '40 mins',
#  '20 mins',
#  '7 mins',
#  '1 hr 15 mins',
#  '6 mins',
#  '30 mins',
#  '1 hr',
#  '1 hr',
#  '1 hr',
#  '15 mins',
#  '25 mins',
#  '45 mins',
#  '30 mins',
#  '5 mins',
#  '15 mins',
#  '10 mins',
#  '50 mins',
#  '40 mins',
#  '10 mins',
#  '15 mins',
#  '5 mins',
#  '35 mins',
#  '1 hr',
#  '30 mins',
#  '35 mins',
#  '5 mins',
#  '30 mins',
#  '20 mins',
#  '30 mins',
#  '10 mins',
#  '30 mins',
#  '35 mins',
#  '1 hr 10 mins',
#  '35 mins',
#  '1 hr 15 mins',
#  '50 mins',
#  '45 mins',
#  '40 mins',
#  '15 mins',
#  '30 mins',
#  '5 hrs 20 mins',
#  '30 mins',
#  '5 mins',
#  '15 mins',
#  '1 hr 20 mins',
#  '1 hr',
#  '20 mins',
#  nan,
#  '45 mins',
#  '20 mins',
#  '1 hr 40 mins',
#  '20 mins',
#  '1 hr 10 mins',
#  '45 mins',
#  '30 mins',
#  '55 mins',
#  '15 mins',
#  '15 mins',
#  '30 mins',
#  '20 mins',
#  '1 hr',
#  '30 mins',
#  '25 mins',
#  '30 mins',
#  '25 mins',
#  '50 mins',
#  '25 mins',
#  '20 mins',
#  '1 hr',
#  '1 hr 20 mins',
#  '20 mins',
#  '30 mins',
#  '45 mins',
#  '35 mins',
#  '45 mins',
#  '1 hr 20 mins',
#  '30 mins',
#  '5 mins',
#  '1 hr 40 mins',
#  '20 mins',
#  '30 mins',
#  '35 mins',
#  '30 mins',
#  '30 mins',
#  '20 mins',
#  '1 hr',
#  '5 mins',
#  '30 mins',
#  '15 mins',
#  '10 mins',
#  '40 mins',
#  '15 mins',
#  '25 mins',
#  '1 hr 30 mins',
#  '5 mins',
#  '15 mins',
#  '30 mins',
#  nan,
#  '15 mins',
#  '30 mins',
#  '1 hr',
#  nan,
#  '55 mins',
#  '30 mins',
#  '1 hr 20 mins',
#  '15 mins',
#  '25 mins',
#  '10 mins',
#  '1 hr 15 mins',
#  '20 mins',
#  '5 mins',
#  '1 hr 5 mins',
#  '45 mins',
#  '30 mins',
#  '50 mins',
#  '40 mins',
#  '30 mins',
#  '5 mins',
#  '35 mins',
#  '20 mins',
#  '45 mins',
#  '45 mins',
#  '1 hr',
#  '35 mins',
#  '1 hr 15 mins',
#  '6 hrs',
#  '25 mins',
#  '5 mins',
#  '5 mins',
#  '5 mins',
#  '15 mins',
#  '5 mins',
#  '5 mins',
#  '1 hr 15 mins',
#  '35 mins']

# %%
s=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sodium')
sodium.append(s.text.split()[1] if c else np.nan)

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'Recipe_Name':Title,
                  "Type":type_of,
                  'Serving':serving,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Cholesterol':cholesterol,
                  'Sodium':sodium,
                  'Fiber':fiber,
                  'Sugar':sugar,
                    'Prepare Time':pre_time,
                  'cooking Time': cook_time,
                  "Total_Time":Time,
                  "Ratings":rating,

                 
                 
                 })
df1.tail(3)
# Out:
#                                 Recipe_Name       Type Serving Protein Fat  \
# 197                 Blueberry Kale Smoothie  Breakfast       1       9  12
# 198                  Banana Cranberry Bread  Breakfast       1       2   2
# 199  Morning Maple Cranberry Pecan Oat Bars  breakfast       1       5  13
#
#     Carbs Calories cholesterol sodium fiber sugar Prepare time cooking time  \
# 197    51      312         NaN    241    10    31            5          NaN
# 198    20       94           4    105     2    11           15          NaN
# 199    27      228         NaN     46     4    12           10           25
#
#        Total_Time Ratings
# 197        5 mins     NaN
# 198  1 hr 15 mins       5
# 199       35 mins       5

# %%
#df1.to_csv("breakfast.csv")

# %%
df1=pd.read_csv('breakfast.csv',index_col=0)
df1
# Out:
#                                      Recipe_Name            Type  Serving  \
# 0                                Protein Waffles  cottage cheese      2.0
# 1                                   Deviled Eggs       appetizer      2.0
# 2                               Crustless Quiche          dinner      1.0
# 3           Spanish Tortilla with Pimenton Aioli       appetizer      1.0
# 4                               Corned Beef Hash       breakfast      1.0
# ..                                           ...             ...      ...
# 195          Roasted Strawberry Protein Smoothie  cottage cheese      1.0
# 196  Kale, Banana, Chia, Hemp Superfood Smoothie       breakfast      1.0
# 197                      Blueberry Kale Smoothie       Breakfast      1.0
# 198                       Banana Cranberry Bread       Breakfast      1.0
# 199       Morning Maple Cranberry Pecan Oat Bars       breakfast      1.0
#
#      Protein   Fat  Carbs  Calories  cholesterol  sodium  fiber  sugar  \
# 0        8.5   4.5   12.0     121.0         81.0   224.5    1.5    1.5
# 1        6.3   7.5    1.0      96.8        187.0   156.1    NaN    0.3
# 2       20.0  12.5    5.0     215.0        193.0   620.0    1.0    2.5
# 3        9.0  14.5   21.5     247.0        188.0   363.5    2.0    2.5
# 4       14.5  16.0   26.0     300.0         62.5   782.5    3.5    6.5
# ..       ...   ...    ...       ...          ...     ...    ...    ...
# 195     16.0   3.4   33.0     213.0          5.5   360.0    7.5   27.0
# 196      8.0  10.0   30.0     220.0          NaN   158.0    8.0   14.0
# 197      9.0  12.0   51.0     312.0          NaN   241.0   10.0   31.0
# 198      2.0   2.0   20.0      94.0          4.0   105.0    2.0   11.0
# 199      5.0  13.0   27.0     228.0          NaN    46.0    4.0   12.0
#
#      Prepare time  cooking time    Total_Time  Ratings
# 0            10.0           5.0       15 mins     4.90
# 1            10.0          15.0       25 mins     4.78
# 2            15.0          40.0       55 mins     4.88
# 3            15.0           NaN  1 hr 15 mins     4.44
# 4            10.0          15.0       25 mins     4.75
# ..            ...           ...           ...      ...
# 195           3.0          12.0       15 mins     4.63
# 196           5.0           NaN        5 mins     4.75
# 197           5.0           NaN        5 mins      NaN
# 198          15.0           NaN  1 hr 15 mins     5.00
# 199          10.0          25.0       35 mins     5.00
#
# [200 rows x 15 columns]

# %%
df1['Type'].unique()
# Out:
# array(['cottage cheese', 'appetizer', 'dinner', 'breakfast', 'Breakfast',
#        'dessert', 'Cottage Cheese', 'snacks', 'lunch', 'Instant Pot',
#        'Appetizer', 'Asparagus', 'Quinoa'], dtype=object)

# %% [raw]
# for i in range(len(df1['Recipe_Name'])):
#     a=re.findall('.*[Ee]gg.*|.*[sS]ausage.*|.*Omelet.*|.*Goat.*|.*Beef.*|.*Bagels.*|.*Bagel.*|.*Quiche',df1['Recipe_Name'][i])
#
#     if len(a)>=1:
#         df1['veg/non_veg'][i]='non veg'
#     else:
#         df1['veg/non_veg'][i]='veg'

# %%
df1
# Out:
#                                      Recipe_Name            Type  Serving  \
# 0                                Protein Waffles  cottage cheese      2.0
# 1                                   Deviled Eggs       appetizer      2.0
# 2                               Crustless Quiche          dinner      1.0
# 3           Spanish Tortilla with Pimenton Aioli       appetizer      1.0
# 4                               Corned Beef Hash       breakfast      1.0
# ..                                           ...             ...      ...
# 195          Roasted Strawberry Protein Smoothie  cottage cheese      1.0
# 196  Kale, Banana, Chia, Hemp Superfood Smoothie       breakfast      1.0
# 197                      Blueberry Kale Smoothie       Breakfast      1.0
# 198                       Banana Cranberry Bread       Breakfast      1.0
# 199       Morning Maple Cranberry Pecan Oat Bars       breakfast      1.0
#
#      Protein   Fat  Carbs  Calories  cholesterol  sodium  fiber  sugar  \
# 0        8.5   4.5   12.0     121.0         81.0   224.5    1.5    1.5
# 1        6.3   7.5    1.0      96.8        187.0   156.1    NaN    0.3
# 2       20.0  12.5    5.0     215.0        193.0   620.0    1.0    2.5
# 3        9.0  14.5   21.5     247.0        188.0   363.5    2.0    2.5
# 4       14.5  16.0   26.0     300.0         62.5   782.5    3.5    6.5
# ..       ...   ...    ...       ...          ...     ...    ...    ...
# 195     16.0   3.4   33.0     213.0          5.5   360.0    7.5   27.0
# 196      8.0  10.0   30.0     220.0          NaN   158.0    8.0   14.0
# 197      9.0  12.0   51.0     312.0          NaN   241.0   10.0   31.0
# 198      2.0   2.0   20.0      94.0          4.0   105.0    2.0   11.0
# 199      5.0  13.0   27.0     228.0          NaN    46.0    4.0   12.0
#
#      Prepare time  cooking time    Total_Time  Ratings
# 0            10.0           5.0       15 mins     4.90
# 1            10.0          15.0       25 mins     4.78
# 2            15.0          40.0       55 mins     4.88
# 3            15.0           NaN  1 hr 15 mins     4.44
# 4            10.0          15.0       25 mins     4.75
# ..            ...           ...           ...      ...
# 195           3.0          12.0       15 mins     4.63
# 196           5.0           NaN        5 mins     4.75
# 197           5.0           NaN        5 mins      NaN
# 198          15.0           NaN  1 hr 15 mins     5.00
# 199          10.0          25.0       35 mins     5.00
#
# [200 rows x 15 columns]

# %%
df1[['Recipe_Name',"veg/non_veg"]].head(60)
# Out:
#                                           Recipe_Name veg/non_veg
# 0                                     Protein Waffles         veg
# 1                                        Deviled Eggs     non veg
# 2                                    Crustless Quiche     non veg
# 3                Spanish Tortilla with Pimenton Aioli         veg
# 4                                    Corned Beef Hash     non veg
# 5                                     Green Shakshuka         veg
# 6                Whole Wheat Irish Soda Bread Muffins         veg
# 7                              High-Protein Egg Bagel     non veg
# 8                      Carrot Banana Protein Smoothie         veg
# 9                    Chocolate Oat Flour Banana Bread         veg
# 10                                     Mushroom Toast         veg
# 11            Smoked Turkey Sausage Breakfast Skillet     non veg
# 12       Breakfast Casserole with Spinach and Sausage     non veg
# 13                                   Cheddar Biscuits         veg
# 14                                  Cornbread Muffins         veg
# 15                               Pumpkin Bread Recipe         veg
# 16                         Pumpkin Baked Oatmeal Cups         veg
# 17                                     Apple Turnover         veg
# 18                                  Classic Egg Salad     non veg
# 19                Mini Pumpkin Chocolate Chip Muffins         veg
# 20                                Banana Bread Recipe         veg
# 21                     Cinnamon-Raisin Overnight Oats         veg
# 22                                        Mini Quiche     non veg
# 23                              Babka-Inspired Bagels     non veg
# 24                            Feta Eggs with Zucchini     non veg
# 25                                     Zucchini Bread         veg
# 26                                 Loaded Egg Muffins     non veg
# 27                 Protein Bagels with Cottage Cheese     non veg
# 28                          Greek Cottage Cheese Bowl         veg
# 29                    Broccoli and Cheese Egg Muffins     non veg
# 30                  English Muffin Breakfast Sandwich         veg
# 31                   20+ High Protein Breakfast Ideas         veg
# 32            Roasted Strawberry Almond Flour Muffins         veg
# 33                                     Huevos Pericos         veg
# 34                                Green Smoothie Bowl         veg
# 35            Insanely Good Blueberry Oatmeal Muffins         veg
# 36                                      Artichoke Pie         veg
# 37                         Hash Brown Egg White Nests     non veg
# 38  Tropical Chia Pudding Breakfast Bowl (High Pro...         veg
# 39   High Protein Egg White Muffins with Turkey Bacon     non veg
# 40                   Air Fryer Breakfast Banana Split         veg
# 41                             Zoats or Zucchini Oats         veg
# 42        Breakfast Strata with Sausage and Mushrooms     non veg
# 43                         Slow Cooker Steel Cut Oats         veg
# 44  Bacon Spinach Breakfast Casserole with Gruyère...         veg
# 45                           Savory Steel Cut Oatmeal         veg
# 46               High-Protein Zucchini Omelet for One     non veg
# 47              High-Protein Enchilada Scrambled Eggs     non veg
# 48                           Apple Pie Overnight Oats         veg
# 49             Avocado Toast with Egg – Four (4) Ways     non veg
# 50                               Pumpkin Banana Bread         veg
# 51                           Lox and Eggs with Onions     non veg
# 52           Whole Wheat Pumpkin Pancakes with Pecans         veg
# 53                       Peanut Butter Banana Muffins         veg
# 54                       Cream Cheese Pumpkin Muffins         veg
# 55                             Pumpkin Overnight Oats         veg
# 56                Avocado Toast with Halloumi and Egg     non veg
# 57                 15-Minute Protein Chia Seed Cereal         veg
# 58                       Three-Cheese Zucchini Quiche     non veg
# 59                 Pineapple Chia with Cottage Cheese         veg
