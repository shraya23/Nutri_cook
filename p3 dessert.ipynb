# %%
import re
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %%
url1='https://www.skinnytaste.com/recipe-index/?_course=dessert'
page=requests.get(url1)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)
#soup

# %%
main=soup.find_all('span',class_='wprm-total-time')
main
# Out:
# [<span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">50</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">20</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">4</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hrs</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">59</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">40</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">45</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">20</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">20</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">30</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">7</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">25</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">10</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">10</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">13</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">15</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span> <span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">15</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">1</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hr</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">15</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">20</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>]

# %%
URL=['https://www.skinnytaste.com/recipe-index/?_course=dessert']
for i in range(2,11):
    URL.append(URL[0]+'&_paged='+str(i))
    
    
URL
# Out:
# ['https://www.skinnytaste.com/recipe-index/?_course=dessert',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=2',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=3',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=4',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=5',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=6',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=7',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=8',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=9',
#  'https://www.skinnytaste.com/recipe-index/?_course=dessert&_paged=10']

# %% [markdown]
# ## Time- column

# %%
time=[]
c=0
for i in main:
    time.append(i.text)
    c+=1
time,c
# Out:
# (['1 hr',
#   '1 hr 5 mins',
#   '50 mins',
#   '1 hr 20 mins',
#   '4 hrs 59 mins',
#   '40 mins',
#   '45 mins',
#   '1 hr 20 mins',
#   '20 mins',
#   '30 mins',
#   '7 mins',
#   '25 mins',
#   '1 hr 10 mins',
#   '1 hr 10 mins',
#   '1 hr 13 mins',
#   '15 mins',
#   '1 hr 15 mins',
#   '1 hr',
#   '15 mins',
#   '20 mins'],
#  20)

# %%
# a=re.findall('href=\"(.+)"><img',str(url[0]))
# a[0].split(' ')[0].split('"')[0]
# Out:
# 'https://www.skinnytaste.com/italian-sub-salad/'

# %%
#links
url=soup.find_all('div',class_='post-thumb-img-content post-thumb')
sub_url=[]
for i in url:
    a=re.findall('href=\"(.+)"><img',str(i))
    sub_url.append(a[0].split(' ')[0].split('"')[0])
sub_url
# Out:
# ['https://www.skinnytaste.com/5-ingredient-almond-cake-with-fresh/',
#  'https://www.skinnytaste.com/lemon-coconut-almond-cake/',
#  'https://www.skinnytaste.com/lemon-poppy-seed-cupcakes/',
#  'https://www.skinnytaste.com/chocolate-oat-flour-banana-bread/',
#  'https://www.skinnytaste.com/cottage-cheese-cheesecake/',
#  'https://www.skinnytaste.com/to-die-for-coconut-cookies/',
#  'https://www.skinnytaste.com/snowman-chocolate-bark/',
#  'https://www.skinnytaste.com/coconut-macaroons/',
#  'https://www.skinnytaste.com/best-low-fat-chocolate-chip-cookies/',
#  'https://www.skinnytaste.com/low-fat-chewy-chocolate-chip-oatmeal/',
#  'https://www.skinnytaste.com/pumpkin-mug-cake/',
#  'https://www.skinnytaste.com/pumpkin-chocolate-chip-cookies/',
#  'https://www.skinnytaste.com/apple-turnover/',
#  'https://www.skinnytaste.com/skinny-apple-cobbler/',
#  'https://www.skinnytaste.com/babka-inspired-bagels/',
#  'https://www.skinnytaste.com/grilled-pineapple-2-pts/',
#  'https://www.skinnytaste.com/blueberry-galette/',
#  'https://www.skinnytaste.com/super-moist-carrot-cake-with-cream/',
#  'https://www.skinnytaste.com/chocolate-brownie-date-balls/',
#  'https://www.skinnytaste.com/healthy-chocolate-chip-oat-cookies/']

# %%
# converting above urls(html) into string data

for i in sub_url:
    page=requests.get(i)
    soup = BeautifulSoup(page.text)

soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nChicken Nuggets - Skinnytaste\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\nSearch...\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n Subscribe and get the latest recipes!\n \n\n\n\nAbout Gina\nContact\nTravel\nMy Shop\n \n\n \n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\nHome\nRecipes\n\nMenu Toggle\n\n\n\n\n\nRecipe Finder\n\n\nCategory Index\n\n\nDiet\n\nMenu Toggle\n\n\n\n\n\nWeight Watchers\n\n\nDairy Free\n\n\nGluten Free\n\n\nHigh Protein\n\n\nKeto\n\n\nLow Carb\n\n\nLow Sodium\n\n\nPaleo\n\n\nVegan Recipes\n\n\nVegetarian\n\n\nWhole 30\n\n\nCourse\n\nMenu Toggle\n\n\n\n\n\nBreakfast\n\n\nLunch\n\n\nAppetizers\n\n\nDinner\n\n\nSalad\n\n\nSides\n\n\nSoup\n\n\nDessert\n\n\nDrinks\n\n\nSnacks\n\n\nHoliday Recipes\n\n\nCookbooks\n\nMenu Toggle\n\n\n\n\n\nMy Cookbooks\n\n\nCookbook Index\n\n\nMeal Plans\n \n\n\n\n\n\n\n\n\n\n\n\n\nSearchSearch\n\nRecipe Index\nCookbook Index\n\n \n\n\n\n\n\n\n\nBy Course\n\nMenu Toggle\n\n\n\n\n\nBreakfast\n\n\nLunch\n\n\nDinner\n\n\nAppetizers\n\n\nSalad\n\n\nSides\n\n\nSoup\n\n\nDessert\n\n\nDrinks\n\n\nSnacks\n\n\nHoliday Recipes\n\n\nBy Diet\n\nMenu Toggle\n\n\n\n\n\nWeight Watchers\n\n\nDairy Free\n\n\nGluten Free\n\n\nHigh Protein\n\n\nKeto\n\n\nLow Carb\n\n\nLow Sodium\n\n\nPaleo\n\n\nVegan Recipes\n\n\nVegetarian\n\n\nWhole 30\n\n\nBy Main Ingredient\n\nMenu Toggle\n\n\n\n\n\nBeef Recipes\n\n\nChicken Recipes\n\n\nFish Recipes\n\n\nLamb Recipes\n\n\nPasta Recipes\n\n\nPork Recipes\n\n\nPumpkin Recipes\n\n\nSeafood Recipes\n\n\nShrimp Recipes\n\n\nTurkey Recipes\n\n\nBy Method\n\nMenu Toggle\n\n\n\n\n\nCasseroles\n\n\nGrilling Recipes\n\n\nNo Cook\n\n\nOne Pot Recipes\n\n\nBy Occasion\n\nMenu Toggle\n\n\n\n\n\nBack To School\n\n\nChristmas\n\n\nCinco De Mayo\n\n\nEaster Recipes\n\n\nFather’s Day\n\n\nHalloween\n\n\nJuly 4th\n\n\nMemorial Day\n\n\nMother’s Day Brunch\n\n\nSt Patrick’s Day Recipes\n\n\nSuper Bowl Recipes\n\n\nThanksgiving Recipes\n\n\nValentine’s Day Recipes\n\n\n \n\n\n\n\n\n\n\n\nSearch...\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n Subscribe and get the latest recipes!\n \n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\nMain Menu\n\n \n\n\n\n\n\n\n\n\n\nBy Course\n\nMenu Toggle\n\n\n\n\n\nBreakfast\n\n\nLunch\n\n\nDinner\n\n\nAppetizers\n\n\nSalad\n\n\nSides\n\n\nSoup\n\n\nDessert\n\n\nDrinks\n\n\nSnacks\n\n\nHoliday Recipes\n\n\nBy Diet\n\nMenu Toggle\n\n\n\n\n\nWeight Watchers\n\n\nDairy Free\n\n\nGluten Free\n\n\nHigh Protein\n\n\nKeto\n\n\nLow Carb\n\n\nLow Sodium\n\n\nPaleo\n\n\nVegan Recipes\n\n\nVegetarian\n\n\nWhole 30\n\n\nBy Main Ingredient\n\nMenu Toggle\n\n\n\n\n\nBeef Recipes\n\n\nChicken Recipes\n\n\nFish Recipes\n\n\nLamb Recipes\n\n\nPasta Recipes\n\n\nPork Recipes\n\n\nPumpkin Recipes\n\n\nSeafood Recipes\n\n\nShrimp Recipes\n\n\nTurkey Recipes\n\n\nBy Method\n\nMenu Toggle\n\n\n\n\n\nCasseroles\n\n\nGrilling Recipes\n\n\nNo Cook\n\n\nOne Pot Recipes\n\n\nBy Occasion\n\nMenu Toggle\n\n\n\n\n\nBack To School\n\n\nChristmas\n\n\nCinco De Mayo\n\n\nEaster Recipes\n\n\nFather’s Day\n\n\nHalloween\n\n\nJuly 4th\n\n\nMemorial Day\n\n\nMother’s Day Brunch\n\n\nSt Patrick’s Day Recipes\n\n\nSuper Bowl Recipes\n\n\nThanksgiving Recipes\n\n\nValentine’s Day Recipes\n\n\n \n\nRecipe Finder\nCategory Index\nAbout Gina\nMy Shop\nMy Cookbooks\nCookbook Index\nTravel\nContact\n \n\n\n\n\n \n\nSkinnytaste > Recipes > Kid Friendly > Chicken Nuggets \n\n\n\n\n\nChicken Nuggets\n\n\n\n\n\n\n\n\n \n4.92 from 34 votes \n65 Comments on Chicken Nuggets \n\n\n\n7 Cals: 280 Protein: 28 Carbs: 13 Fats: 13 30 mins \n\nJump to Recipe\nSave to ListSaved to List!\n  Save Recipe Recipe Saved! \n\n\n\n\n\n\n\n\n\n11619\nshares\n\n\n\n \n\n\n\n\n \n\n\n\n\n \n\n\n\n\n \n\n\n\n\n \n\n\n\n\nThis post may contain affiliate links. Read my disclosure policy.\nThese picky-kid-approved, healthy Chicken Nuggets made with ground chicken ar ...

# %%
for i in sub_url:
    page=requests.get(i)
    soup = BeautifulSoup(page.text)
    urls=[]
    single=[]
    for j in soup.find_all('a'):
        single.append(j.text)
        urls.append(single)
urls
# Out:
# [['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
# ...
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n'],
#  ['\nSkip to content',
#   ' Subscribe and get the latest recipes!',
#   'About Gina',
#   'Contact',
#   'Travel',
#   'My Shop',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Home',
#   'Recipes\n\n',
#   '\n\nRecipe Finder',
#   '\n\nCategory Index',
#   'Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nAppetizers',
#   '\n\nDinner',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'Cookbooks\n\n',
#   '\n\nMy Cookbooks',
#   '\n\nCookbook Index',
#   'Meal Plans',
#   'Recipe Index',
#   'Cookbook Index',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   ' Subscribe and get the latest recipes!',
#   '',
#   '\n\n',
#   'By Course\n\n',
#   '\n\nBreakfast',
#   '\n\nLunch',
#   '\n\nDinner',
#   '\n\nAppetizers',
#   '\n\nSalad',
#   '\n\nSides',
#   '\n\nSoup',
#   '\n\nDessert',
#   '\n\nDrinks',
#   '\n\nSnacks',
#   '\n\nHoliday Recipes',
#   'By Diet\n\n',
#   '\n\nWeight Watchers',
#   '\n\nDairy Free',
#   '\n\nGluten Free',
#   '\n\nHigh Protein',
#   '\n\nKeto',
#   '\n\nLow Carb',
#   '\n\nLow Sodium',
#   '\n\nPaleo',
#   '\n\nVegan Recipes',
#   '\n\nVegetarian',
#   '\n\nWhole 30',
#   'By Main Ingredient\n\n',
#   '\n\nBeef Recipes',
#   '\n\nChicken Recipes',
#   '\n\nFish Recipes',
#   '\n\nLamb Recipes',
#   '\n\nPasta Recipes',
#   '\n\nPork Recipes',
#   '\n\nPumpkin Recipes',
#   '\n\nSeafood Recipes',
#   '\n\nShrimp Recipes',
#   '\n\nTurkey Recipes',
#   'By Method\n\n',
#   '\n\nCasseroles',
#   '\n\nGrilling Recipes',
#   '\n\nNo Cook',
#   '\n\nOne Pot Recipes',
#   'By Occasion\n\n',
#   '\n\nBack To School',
#   '\n\nChristmas',
#   '\n\nCinco De Mayo',
#   '\n\nEaster Recipes',
#   '\n\nFather’s Day',
#   '\n\nHalloween',
#   '\n\nJuly 4th',
#   '\n\nMemorial Day',
#   '\n\nMother’s Day Brunch',
#   '\n\nSt Patrick’s Day Recipes',
#   '\n\nSuper Bowl Recipes',
#   '\n\nThanksgiving Recipes',
#   '\n\nValentine’s Day Recipes',
#   'Recipe Finder',
#   'Category Index',
#   'About Gina',
#   'My Shop',
#   'My Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'Contact',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Skinnytaste',
#   'Recipes',
#   'Kid Friendly',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.92 from 34 votes',
#   '65 Comments on Chicken Nuggets',
#   'Jump to Recipe',
#   '  Save Recipe',
#   ' Recipe Saved!',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n',
#   'disclosure policy',
#   'cauliflower rice',
#   'air fryer',
#   'Baked Chicken Nuggets',
#   'Air Fryer Chicken Nuggets',
#   'this recipe',
#   'BBQ sauce',
#   'lunch',
#   'french fries',
#   'mac and cheese',
#   'roasted broccoli',
#   'green beans',
#   'Air Fryer Buffalo Chicken Nuggets',
#   'Air Fryer Popcorn Chicken',
#   'Pickle-Brined Baked Chicken Tenders',
#   'Air Fryer Chicken Tenders',
#   'Tortilla-Encrusted Chicken Tenders',
#   '',
#   'Dinner',
#   ' Print',
#   ' Rate',
#   ' Pin',
#   '  Save',
#   ' Saved!',
#   'WW Points',
#   'kosher salt',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'large egg',
#   'seasoned breadcrumbs',
#   'leave a rating and comment',
#   '@skinnytaste',
#   '#skinnytaste',
#   ' Share This',
#   '   Follow Us',
#   ' Pin This',
#   ' Rate This',
#   'Air Fryer Recipes',
#   'Back To School',
#   'Chicken Recipes',
#   'Dairy Free',
#   'Dinner Ideas',
#   'Gluten Free',
#   'High Protein Recipes',
#   'Kid Friendly',
#   'Lunch',
#   'Recipes',
#   'Under 30 Minutes',
#   'Weight Watchers – WW Recipes',
#   '  ',
#   'Gina',
#   '\n\n Previous Post\nClassic Egg Salad\n',
#   '\nNext Post \nStuffed Shells with Meat Sauce\n\n',
#   '',
#   'Air Fryer Recipes',
#   'Dairy Free',
#   'Freezer Meals',
#   'Gluten Free',
#   'Keto Recipes',
#   'Kid Friendly',
#   'Low Carb',
#   'Meal Prep Recipes',
#   'Paleo',
#   'Pressure Cooker Recipes',
#   'Slow Cooker Recipes',
#   'Under 30 Minutes',
#   'Vegetarian Meals',
#   'Whole30 Recipes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'Bookshop.org',
#   'Indiebound',
#   'Books-a-Million',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Book-a-Million',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'Indigo',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Target',
#   'iBooks',
#   '',
#   'Amazon',
#   'Barnes & Noble',
#   'IndieBound',
#   'Crispy Oven Roasted Baby Potatoes',
#   'Green Goddess Potato Salad',
#   'One-Pot Orzo with Sausage, Spinach and Corn',
#   'The 14 Best Grill Tools For Your Next Backyard BBQ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'More Cookbooks ',
#   "Learn more about Mailchimp's privacy practices here.",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Breakfast',
#   'Lunch',
#   'Dinner',
#   'Sides',
#   'Dessert',
#   'Spring Recipes',
#   'Summer',
#   'Fall',
#   'Winter',
#   'Holidays',
#   'Recipe Finder',
#   'Meal Plans',
#   'Shop Products',
#   'Cookbooks',
#   'Cookbook Index',
#   'Travel',
#   'About Me',
#   'Privacy',
#   'Cookie Policy',
#   'Contact Me',
#   'Swift Horse Marketing ',
#   ' \n\n\n',
#   ' \n\n\n',
#   ' \n\n\n']]

# %%
# urls=[]
# single=[]
# for j in soup.find_all('a'):
#     single.append(j.text)

#     urls.append(single)
# single
# urls[0]

# %%
link='https://www.skinnytaste.com/5-ingredient-almond-cake-with-fresh/'
page=requests.get(link)
soup = BeautifulSoup(page.text)
#soup

# %%
#title
soup.find_all('h1')[0].text
# Out:
# 'Almond Cake'

# %%
#rating
soup.find_all('span',class_='wprm-recipe-rating-average')[0].text
# Out:
# '4.86'

# %%
#calories
c=soup.find_all('span',class_='recipe-meta-value value-calories')[0].text
c.split(' ')[1]
# Out:
# '179'

# %%
#protein
p=soup.find_all('span',class_='recipe-meta-value value-protein')[0].text
p.split(' ')[1]
# Out:
# '7'

# %%
#carbs
c=soup.find_all('span',class_='recipe-meta-value value-carbs')[0].text
c.split(' ')[1]
# Out:
# '17'

# %%
#fats
f=soup.find_all('span',class_='recipe-meta-value value-fat')[0].text
f.split(' ')[1]
# Out:
# '11'

# %%
#serving
s=soup.find_all('span',class_='wprm-recipe-nutrition-with-unit')
s[0].text
# Out:
# '1 /12th'

# %%
#type
t=soup.find_all('span',class_= 'wprm-recipe-course wprm-block-text-normal')
t[0].text
# Out:
# 'Dessert'

# %%
#ingredients
ii=soup.find_all('strong')
re.findall('\>(\w+)',str(ii))
# Out:
# ['Lettuce',
#  'High',
#  'Cheese',
#  'Vegetables',
#  'Italian',
#  'Italian',
#  'Make',
#  'Meat',
#  'Vegetarian',
#  'Olives',
#  'Tomatoes',
#  'Onions',
#  'Cheese',
#  'Briny',
#  'Vegetables',
#  'Herbs']

# %%
ii
# Out:
# [<strong>“sub in a tub”</strong>,
#  <strong>“chopped sub salad,”</strong>,
#  <strong>Lettuce:</strong>,
#  <strong>High-Protein Toppings:</strong>,
#  <strong>Cheese: </strong>,
#  <strong>Vegetables: </strong>,
#  <strong>Italian Sub Salad Dressing: </strong>,
#  <strong>Italian Salad Dressing:</strong>,
#  <strong>Make the Salad:</strong>,
#  <strong>Meat: </strong>,
#  <strong>Vegetarian Italian Salad: </strong>,
#  <strong>Olives: </strong>,
#  <strong>Tomatoes: </strong>,
#  <strong>Onions: </strong>,
#  <strong>Cheese:</strong>,
#  <strong>Briny/Pickled Substitutions:</strong>,
#  <strong>Vegetables: </strong>,
#  <strong>Herbs: </strong>]

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=dessert']
Time = []
sub_url = []

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)
    print(page)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
print(len(Time))  
print(len(sub_url))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# 199
# 199

# %%
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]
cholesterol=[]
sodium=[]
fiber=[]
sugar=[]
pre_time=[]
cook_time=[]
    
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find('h1').text)
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)
    
    c=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-cholesterol')
    cholesterol.append(c.text.split(' ')[1] if c else np.nan)
    
    sod=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sodium')
    sodium.append(sod.text.split()[1] if sod else np.nan)
    
    f=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-fiber')
    fiber.append(f.text.split()[1] if f else np.nan)
    
    ss=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sugar')
    sugar.append(ss.text.split()[1] if ss else np.nan)
    
    pt=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-prep_time wprm-recipe-prep_time-minutes')
    pre_time.append(pt.text.split()[0] if pt else np.nan)
    
    ct=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes')
    cook_time.append(ct.text.split()[0] if ct else np.nan)
    
    
    
print(len(Title))
print(len(rating))
print(len(protein))
print(len(calories))
print(len(carbs))
print(len(fat))
print(len(serving))
print(len(type_of))
print(len(cholesterol))
print(len(sodium))
print(len(fiber))
print(len(sugar))
print(len(pre_time))
print(len(cook_time))
# Out:
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199
# 199

# %%
df3=pd.DataFrame({'Recipe_Name':Title,
                  "Type":type_of,
                  'Serving':serving,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'cholesterol':cholesterol,
                  'sodium':sodium,
                  'fiber':fiber,
                  'sugar':sugar,
                    'Prepare time':pre_time,
                  'cooking time': cook_time,
                  "Total_Time":Time,
                  "Ratings":rating,

                 
                 
                 })
df3.tail(3)
# Out:
#                           Recipe_Name     Type Serving Protein  Fat Carbs  \
# 196            Strawberries and Cream  dessert       3     0.3  1.7   6.8
# 197  Banana Apricot Puff Pastry Tarts  dessert       1     NaN  NaN   NaN
# 198               Black Bean Brownies  Dessert       1     2.9  2.6    28
#
#     Calories cholesterol sodium fiber sugar Prepare time cooking time  \
# 196     31.2         NaN    NaN   1.2   5.8          NaN          NaN
# 197      NaN         NaN    NaN   NaN   NaN          NaN          NaN
# 198    138.1         NaN    NaN   1.8   NaN          NaN          NaN
#
#     Total_Time Ratings
# 196        NaN     NaN
# 197    40 mins    2.50
# 198        NaN    4.71

# %%
#df3.to_csv("dessert.csv")
df3=pd.read_csv('dessert.csv',index_col=0)
df3
# Out:
#                           Recipe_Name            Type  Serving  Protein   Fat  \
# 0                         Almond Cake         Dessert      1.0      7.0  11.0
# 1           Lemon-Coconut Almond Cake         dessert      1.0      6.5  10.5
# 2           Lemon Poppy Seed Cupcakes         dessert      1.0      3.5   4.0
# 3    Chocolate Oat Flour Banana Bread       Breakfast      1.0      5.5   7.0
# 4           Cottage Cheese Cheesecake  cottage cheese      1.0      6.5  10.5
# ..                                ...             ...      ...      ...   ...
# 194                 Blueberry Compote       Breakfast      2.0      0.5   NaN
# 195                No-Bake Cheesecake         dessert      1.0      3.0  12.0
# 196            Strawberries and Cream         dessert      3.0      0.3   1.7
# 197  Banana Apricot Puff Pastry Tarts         dessert      1.0      NaN   NaN
# 198               Black Bean Brownies         Dessert      1.0      2.9   2.6
#
#      Carbs  Calories  cholesterol  sodium  fiber  sugar  Prepare time  \
# 0     17.0     179.0         47.0    39.0    3.0   13.0          20.0
# 1     20.5     198.0         46.5    32.5    4.0   14.0          20.0
# 2     42.0     152.0         23.5   160.0    1.5    6.5          15.0
# 3     34.5     190.0         34.5   179.5    9.5   11.5          15.0
# 4     15.0     159.0         60.0   243.0    0.5    3.0          15.0
# ..     ...       ...          ...     ...    ...    ...           ...
# 194   22.7      89.0          NaN     NaN    2.0    NaN           NaN
# 195   23.0     181.0         14.5   168.0    1.0    6.5          20.0
# 196    6.8      31.2          NaN     NaN    1.2    5.8           NaN
# 197    NaN       NaN          NaN     NaN    NaN    NaN           NaN
# 198   28.0     138.1          NaN     NaN    1.8    NaN           NaN
#
#      cooking time     Total_Time  Ratings
# 0            40.0           1 hr     4.86
# 1            30.0    1 hr 5 mins     4.91
# 2            25.0        50 mins      NaN
# 3            50.0   1 hr 20 mins     4.97
# 4            44.0  4 hrs 59 mins     4.88
# ..            ...            ...      ...
# 194           NaN            NaN     5.00
# 195           0.0  3 hrs 20 mins     5.00
# 196           NaN            NaN      NaN
# 197           NaN        40 mins     2.50
# 198           NaN            NaN     4.71
#
# [199 rows x 15 columns]

# %%
df3['Type'].unique()
# Out:
# array(['Dessert', 'dessert', 'Breakfast', 'cottage cheese', 'breakfast',
#        'Instant Pot', 'dinner', 'appetizer', 'Snacks', 'lunch'],
#       dtype=object)
