# %% [markdown]
# ## Importing libraries

# %%
import re
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Break fast data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=breakfast-brunch']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')
# Out:
# Done

# %%
df1=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df1.tail(3)
# Out:
#                                     Recipe_Name Ratings    Total_Time Protein  \
# 197                 [[Blueberry Kale Smoothie]]     NaN        5 mins       9
# 198                  [[Banana Cranberry Bread]]       5  1 hr 15 mins       2
# 199  [[Morning Maple Cranberry Pecan Oat Bars]]       5       35 mins       5
#
#     Fat Carbs Calories Serving       Type  \
# 197  12    51      312       1  Breakfast
# 198   2    20       94       1  Breakfast
# 199  13    27      228       1  breakfast
#
#                                                   URLS
# 197  https://www.skinnytaste.com/blueberry-kale-smo...
# 198  https://www.skinnytaste.com/banana-cranberry-b...
# 199  https://www.skinnytaste.com/morning-maple-cran...

# %%
for i in df1['Recipe_Name']:
    print(i)
# Out:
# [<h1 class="entry-title">Protein Waffles</h1>]
# [<h1 class="entry-title">Deviled Eggs</h1>]
# [<h1 class="entry-title">Crustless Quiche</h1>]
# [<h1 class="entry-title">Spanish Tortilla with Pimenton Aioli</h1>]
# [<h1 class="entry-title">Corned Beef Hash</h1>]
# [<h1 class="entry-title">Green Shakshuka</h1>]
# [<h1 class="entry-title">Whole Wheat Irish Soda Bread Muffins</h1>]
# [<h1 class="entry-title">High-Protein Egg Bagel</h1>]
# [<h1 class="entry-title">Carrot Banana Protein Smoothie</h1>]
# [<h1 class="entry-title">Chocolate Oat Flour Banana Bread</h1>]
# [<h1 class="entry-title">Mushroom Toast</h1>]
# [<h1 class="entry-title">Smoked Turkey Sausage Breakfast Skillet</h1>]
# [<h1 class="entry-title">Breakfast Casserole with Spinach and Sausage</h1>]
# [<h1 class="entry-title">Cheddar Biscuits</h1>]
# [<h1 class="entry-title">Cornbread Muffins</h1>]
# [<h1 class="entry-title">Pumpkin Bread Recipe</h1>]
# [<h1 class="entry-title">Pumpkin Baked Oatmeal Cups</h1>]
# [<h1 class="entry-title">Apple Turnover</h1>]
# [<h1 class="entry-title">Classic Egg Salad</h1>]
# [<h1 class="entry-title">Mini Pumpkin Chocolate Chip Muffins</h1>]
# [<h1 class="entry-title">Banana Bread Recipe</h1>]
# [<h1 class="entry-title">Cinnamon-Raisin Overnight Oats</h1>]
# [<h1 class="entry-title">Mini Quiche</h1>]
# [<h1 class="entry-title">Babka-Inspired Bagels</h1>]
# [<h1 class="entry-title">Feta Eggs with Zucchini</h1>]
# [<h1 class="entry-title">Zucchini Bread</h1>]
# [<h1 class="entry-title">Loaded Egg Muffins</h1>]
# [<h1 class="entry-title">Protein Bagels with Cottage Cheese</h1>]
# [<h1 class="entry-title">Greek Cottage Cheese Bowl</h1>]
# [<h1 class="entry-title">Broccoli and Cheese Egg Muffins</h1>]
# [<h1 class="entry-title">English Muffin Breakfast Sandwich</h1>]
# [<h1 class="entry-title">20+ High Protein Breakfast Ideas</h1>]
# [<h1 class="entry-title">Roasted Strawberry Almond Flour Muffins</h1>]
# [<h1 class="entry-title">Huevos Pericos</h1>]
# [<h1 class="entry-title">Green Smoothie Bowl</h1>]
# [<h1 class="entry-title">Insanely Good Blueberry Oatmeal Muffins</h1>]
# [<h1 class="entry-title">Artichoke Pie</h1>]
# [<h1 class="entry-title">Hash Brown Egg White Nests</h1>]
# [<h1 class="entry-title">Tropical Chia Pudding Breakfast Bowl (High Protein)</h1>]
# [<h1 class="entry-title">High Protein Egg White Muffins with Turkey Bacon</h1>]
# [<h1 class="entry-title">Air Fryer Breakfast Banana Split</h1>]
# [<h1 class="entry-title">Zoats or Zucchini Oats</h1>]
# [<h1 class="entry-title">Breakfast Strata with Sausage and Mushrooms</h1>]
# [<h1 class="entry-title">Slow Cooker Steel Cut Oats</h1>]
# [<h1 class="entry-title">Bacon Spinach Breakfast Casserole with Gruyère Cheese</h1>]
# [<h1 class="entry-title">Savory Steel Cut Oatmeal</h1>]
# [<h1 class="entry-title">High-Protein Zucchini Omelet for One</h1>]
# [<h1 class="entry-title">High-Protein Enchilada Scrambled Eggs</h1>]
# [<h1 class="entry-title">Apple Pie Overnight Oats</h1>]
# [<h1 class="entry-title">Avocado Toast with Egg – Four (4) Ways</h1>]
# [<h1 class="entry-title">Pumpkin Banana Bread</h1>]
# [<h1 class="entry-title">Lox and Eggs with Onions</h1>]
# [<h1 class="entry-title">Whole Wheat Pumpkin Pancakes with Pecans</h1>]
# [<h1 class="entry-title">Peanut Butter Banana Muffins</h1>]
# [<h1 class="entry-title">Cream Cheese Pumpkin Muffins</h1>]
# [<h1 class="entry-title">Pumpkin Overnight Oats</h1>]
# [<h1 class="entry-title">Avocado Toast with Halloumi and Egg</h1>]
# [<h1 class="entry-title">15-Minute Protein Chia Seed Cereal</h1>]
# [<h1 class="entry-title">Three-Cheese Zucchini Quiche</h1>]
# [<h1 class="entry-title">Pineapple Chia with Cottage Cheese</h1>]
# [<h1 class="entry-title">Peach Pie Cottage Cheese Bowls</h1>]
# [<h1 class="entry-title">Overnight Oats (How To Make)</h1>]
# [<h1 class="entry-title">Mango Coconut Chia Pudding</h1>]
# [<h1 class="entry-title">Berry Cottage Cheese Breakfast Bowl</h1>]
# [<h1 class="entry-title">Instant Pot Baked Oatmeal Bars</h1>]
# [<h1 class="entry-title">Swiss Chard Frittata</h1>]
# [<h1 class="entry-title">Banana Nut Pancakes</h1>]
# [<h1 class="entry-title">Peanut Butter Breakfast Oatmeal Bowl</h1>]
# [<h1 class="entry-title">Roasted Strawberry Banana Bread</h1>, <h1>How to Make Strawberry Banana Bread</h1>]
# [<h1 class="entry-title">High-Protein Scrambled Eggs with Cottage Cheese</h1>]
# [<h1 class="entry-title">Peanut Butter Oatmeal Protein Cookies</h1>]
# [<h1 class="entry-title">Meal Prep Breakfast Taco Scramble</h1>]
# [<h1 class="entry-title">Cream Cheese-Filled Almond Flour Banana Muffins (Gluten-Free)</h1>]
# [<h1 class="entry-title">Crustless Potato Jalapeño Quiche</h1>]
# [<h1 class="entry-title">Mushroom-Spinach Scrambled Eggs</h1>]
# [<h1 class="entry-title">Healthy 3-Ingredient Banana Oatmeal Cookies</h1>]
# [<h1 class="entry-title">Baked Oatmeal with Blueberries and Bananas</h1>]
# [<h1 class="entry-title">Waffled Vegetable Latkes</h1>]
# [<h1 class="entry-title">Peanut Butter and Jelly Smoothie</h1>]
# [<h1 class="entry-title">Huevos Rancheros</h1>]
# [<h1 class="entry-title">Banana Nut Protein Oats</h1>]
# [<h1 class="entry-title">Strawberry Scones</h1>]
# [<h1 class="entry-title">Asparagus and Swiss Cheese Frittata</h1>]
# [<h1 class="entry-title">Oatmeal Berry Smoothie Bowl</h1>]
# [<h1 class="entry-title">Strawberries and Yogurt Whipped Cream</h1>]
# [<h1 class="entry-title">Protein PB &amp; J Smoothie Bowl</h1>]
# [<h1 class="entry-title">Spanakopita Baked Eggs</h1>]
# [<h1 class="entry-title">Cacio e Pepe Frittata with Cauliflower and Lemony Yogurt</h1>]
# [<h1 class="entry-title">Cottage Cheese Egg and Sausage Frittata</h1>]
# [<h1 class="entry-title">Baked Sweet Potato Egg Cups</h1>]
# [<h1 class="entry-title">Savory Cottage Cheese Bowl</h1>]
# [<h1 class="entry-title">High Protein Bread (Oat Sandwich Rolls)</h1>]
# [<h1 class="entry-title">3-Ingredient Baked Bananas</h1>]
# [<h1 class="entry-title">Breakfast Egg Rolls</h1>]
# [<h1 class="entry-title">Virgin Bloody Mary</h1>]
# [<h1 class="entry-title">Yogurt Sheet Pan Pancakes with Mixed Berries</h1>]
# [<h1 class="entry-title">Lemon Cranberry Scones</h1>]
# [<h1 class="entry-title">Crustless Sausage and Spinach Quiche</h1>]
# [<h1 class="entry-title">Lemon Blueberry Buttermilk Sheet Pan Pancakes</h1>]
# [<h1 class="entry-title">Chocolate Zucchini Bread</h1>]
# [<h1 class="entry-title">Easy Blueberry Buttermilk Cake</h1>]
# [<h1 class="entry-title">Crustless Quiche Lorraine</h1>]
# [<h1 class="entry-title">Caramelized Onion, Red Pepper and Zucchini Frittata</h1>]
# [<h1 class="entry-title">Omelet Tortilla Breakfast Wrap</h1>]
# [<h1 class="entry-title">Banana Pancake Cereal</h1>]
# [<h1 class="entry-title">Superfood Triple Berry Chia Pudding</h1>]
# [<h1 class="entry-title">Lightened Up Blueberry Scones</h1>]
# [<h1 class="entry-title">Tropical Mango Blueberry Lassi</h1>]
# [<h1 class="entry-title">Egg Tomato and Scallion Sandwich</h1>]
# [<h1 class="entry-title">Skillet Mixed Berry Buttermilk Cobbler</h1>]
# [<h1 class="entry-title">Hot Cross Buns</h1>]
# [<h1 class="entry-title">Banana Bread Muffin in a Mug</h1>]
# [<h1 class="entry-title">Chorizo Breakfast Bowls</h1>]
# [<h1 class="entry-title">Chocolate Pistachio Biscotti</h1>]
# [<h1 class="entry-title">Changua (Colombian Milk and Egg Soup)</h1>]
# [<h1 class="entry-title">Breakfast Casserole with Spinach and Feta</h1>]
# [<h1 class="entry-title">Easy Healthy Ground Turkey Chorizo</h1>]
# [<h1 class="entry-title">Banana Nut Bread</h1>]
# [<h1 class="entry-title">Pumpkin Butter</h1>]
# [<h1 class="entry-title">Cinnamon Apple Yogurt Bowls</h1>]
# [<h1 class="entry-title">Baked Oatmeal Recipe with Pears Bananas and Walnuts</h1>]
# [<h1 class="entry-title">Breakfast BLT</h1>]
# [<h1 class="entry-title">Air Fryer Hard Boiled Eggs</h1>]
# [<h1 class="entry-title">Smoked Salmon Breakfast Flatbread</h1>]
# [<h1 class="entry-title">Tex Mex Migas</h1>]
# [<h1 class="entry-title">Veggie Ham and Cheese Breakfast Egg Casserole</h1>]
# [<h1 class="entry-title">Freezer Breakfast Burritos</h1>]
# [<h1 class="entry-title">How To Hard Boil Eggs (Perfect Everytime)</h1>]
# [<h1 class="entry-title">Swiss Chard Eggs Benedict</h1>]
# [<h1 class="entry-title">Yogurt Waffles</h1>]
# [<h1 class="entry-title">Crustless Broccoli Cheddar Quiche</h1>]
# [<h1 class="entry-title">Instant Pot Steel Cut Oats</h1>]
# [<h1 class="entry-title">Huevos Pericos (Colombian Scrambled Eggs)</h1>]
# [<h1 class="entry-title">How To Setup an Easy Bagel Bar Brunch</h1>]
# [<h1 class="entry-title">Tex Mex Breakfast Casserole</h1>]
# [<h1 class="entry-title">Instant Pot Deviled Eggs</h1>]
# [<h1 class="entry-title">Hash Brown Recipe</h1>]
# [<h1 class="entry-title">Maple Pecan Banana Muffins</h1>]
# [<h1 class="entry-title">Bacon Egg and Avocado Breakfast Sandwich</h1>]
# [<h1 class="entry-title">Crustless Summer Zucchini Pie</h1>]
# [<h1 class="entry-title">Spinach Ricotta Quiche</h1>]
# [<h1 class="entry-title">Yogurt Chocolate Chip Muffins</h1>]
# [<h1 class="entry-title">Strawberry Peanut Butter Swirl Smoothie Bowls</h1>]
# [<h1 class="entry-title">Chicken Quiche</h1>]
# [<h1 class="entry-title">Smoked Salmon Pinwheels</h1>]
# [<h1 class="entry-title">Breakfast Pizza</h1>]
# [<h1 class="entry-title">Stuffed Bagel Balls (Baked or Air Fryer)</h1>]
# [<h1 class="entry-title">Czech Crepes with Berries and Cream</h1>]
# [<h1 class="entry-title">Easy Bagel Recipe</h1>]
# [<h1 class="entry-title">Spicy Breakfast Fajitas with Eggs and Guacamole</h1>]
# [<h1 class="entry-title">Gluten-Free, Dairy-Free, Blueberry Oatmeal Muffins</h1>]
# [<h1 class="entry-title">Goat Cheese Herb Omelet with Nova Lox</h1>]
# [<h1 class="entry-title">Asparagus and Lentils with Poached Egg</h1>]
# [<h1 class="entry-title">Breakfast BLT Salad</h1>]
# [<h1 class="entry-title">Instant Pot Hard Boiled Eggs (and Soft Boiled)</h1>]
# [<h1 class="entry-title">Sheet Pan Home Fries</h1>]
# [<h1 class="entry-title">4-Ingredient Flourless Banana-Nut Oatmeal Pancakes</h1>]
# [<h1 class="entry-title">Whole Wheat Pancakes</h1>]
# [<h1 class="entry-title">Crab Cakes Benedict with Avocado Relish</h1>]
# [<h1 class="entry-title">Hummus Avocado Toast</h1>]
# [<h1 class="entry-title">Avocado Toast with Lemon and Kale</h1>]
# [<h1 class="entry-title">Asparagus-Pancetta Potato Hash</h1>]
# [<h1 class="entry-title">Miami Avocado Crab Toast</h1>]
# [<h1 class="entry-title">Open-Faced Omelet with Avocado and Pico de Gallo</h1>]
# [<h1 class="entry-title">Breakfast Burrito Bowl with Spiced Butternut Squash</h1>]
# [<h1 class="entry-title">Spinach, Feta, and Artichoke Breakfast Bake</h1>]
# [<h1 class="entry-title">Open-Faced Omelet with Feta, Roasted Tomatoes and Spinach</h1>]
# [<h1 class="entry-title">Leftover Turkey and Sweet Potato Frittata</h1>]
# [<h1 class="entry-title">Berry Quinoa Breakfast Bowls</h1>]
# [<h1 class="entry-title">Pumpkin Pecan Banana Bread</h1>]
# [<h1 class="entry-title">Pumpkin Spice Cream Cheese</h1>]
# [<h1 class="entry-title">Eggs Pizzaiola</h1>]
# [<h1 class="entry-title">Cucumber, Parsley, Pineapple and Lemon Smoothie</h1>]
# [<h1 class="entry-title">Chocolate Chip Zucchini Bread</h1>]
# [<h1 class="entry-title">Summer Mango Stone Fruit Smoothie</h1>]
# [<h1 class="entry-title">Overnight Oats with Figs and Honey</h1>]
# [<h1 class="entry-title">Blueberry Banana Bread</h1>]
# [<h1 class="entry-title">Baked Eggs in Spaghetti Squash Nests</h1>]
# [<h1 class="entry-title">Skillet Sweet Potato Chicken Hash with Eggs</h1>]
# [<h1 class="entry-title">Bell Pepper and Potato Frittata</h1>]
# [<h1 class="entry-title">Petite Crustless Quiche</h1>]
# [<h1 class="entry-title">Turkey Sausage Patties From Scratch</h1>]
# [<h1 class="entry-title">Avocado Toast Egg-in-a-Hole</h1>]
# [<h1 class="entry-title">Poached Pears with Yogurt</h1>]
# [<h1 class="entry-title">Avocado Egg Salad and Salmon Sandwich</h1>]
# [<h1 class="entry-title">Sausage, Cheese and Veggie Breakfast Casserole</h1>]
# [<h1 class="entry-title">Mini Greek Spinach Pies</h1>]
# [<h1 class="entry-title">Gluten-Free Banana Nut Bread</h1>]
# [<h1 class="entry-title">Baked Pears with Walnuts and Honey</h1>]
# [<h1 class="entry-title">Apple Nut Bread</h1>]
# [<h1 class="entry-title">Coconut Lime Raspberry Chia Pudding</h1>]
# [<h1 class="entry-title">Summer Quinoa Breakfast Bowl</h1>]
# [<h1 class="entry-title">Pina Banana Colada Smoothie</h1>]
# [<h1 class="entry-title">Bali Banana Date Smoothie</h1>]
# [<h1 class="entry-title">Superfood PB Banana and Cacao Green Smoothie</h1>]
# [<h1 class="entry-title">Roasted Strawberry Protein Smoothie</h1>]
# [<h1 class="entry-title">Kale, Banana, Chia, Hemp Superfood Smoothie</h1>]
# [<h1 class="entry-title">Blueberry Kale Smoothie</h1>]
# [<h1 class="entry-title">Banana Cranberry Bread</h1>]
# [<h1 class="entry-title">Morning Maple Cranberry Pecan Oat Bars</h1>]

# %% [markdown]
# ### 2. Lunch data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=lunch']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]
c=1

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)
    print(page)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)
    c=c+1
print(c)
print('Done')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# 201
# Done

# %%
df2=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df2.tail(3)

# %% [markdown]
# ### 3. Dessert data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=dessert']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)
    print(page)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')

# %%
df3=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df3.tail(3)

# %% [markdown]
# ### 4. Drinks Data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=drinks']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 4):
    URL.append(URL[0] + '&_paged=' + str(i))  # 2 pages(58rows)

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)
    print(page)


    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')

# %%
df4=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df4.tail(3)

# %% [markdown]
# ### 5. Appetizers Data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=appetizers']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages(186 rows)

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')

# %%
df5=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df5.tail(3)

# %% [markdown]
# ### 6. Soup Data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=soup']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 7):
    URL.append(URL[0] + '&_paged=' + str(i))  # (117 rows)

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')

# %%
df6=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df6.tail(3)

# %% [markdown]
# ### 7. Dinner Data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=dinner-recipes']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')

# %%
df7=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df7.tail(3)

# %% [markdown]
# ### 8. Salad Data

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=salad']
Time = []
sub_url = []
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]

for i in range(2, 11):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find_all('h1'))
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)

print('Done')

# %%
df8=pd.DataFrame({'Recipe_Name':Title,
                  "Ratings":rating,
                  "Total_Time":Time,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'Serving':serving,
                  "Type":type_of,
                  'URLS':sub_url })
df8.tail(3)

# %% [markdown]
# ## Joining all Datasets

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis=0,ignore_index=True)

# %%
df

# %% [markdown]
# ## Saving data into local Directory

# %%
df.to_csv("dataset.csv")
