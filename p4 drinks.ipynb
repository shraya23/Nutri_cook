# %%
import re
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %%
url1='https://www.skinnytaste.com/recipe-index/?_course=drinks'
page=requests.get(url1)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)
#soup

# %%
main=soup.find_all('span',class_='wprm-total-time')
#main
# Out:
# [<span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">10</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">10</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-hours wprm-recipe-total_time wprm-recipe-total_time-hours">3</span> <span class="wprm-recipe-details-unit wprm-recipe-details-unit-hours wprm-recipe-total_time-unit wprm-recipe-total_timeunit-hours">hrs</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">10</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">10</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">20</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">15</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>,
#  <span class="wprm-total-time"><span class="wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-total_time wprm-recipe-total_time-minutes">5</span> <span class="wprm-recipe-details-unit wprm-recipe-details-minutes wprm-recipe-total_time-unit wprm-recipe-total_timeunit-minutes">mins</span></span>]

# %%
URL=['https://www.skinnytaste.com/recipe-index/?_course=drinks']
for i in range(2,11):
    URL.append(URL[0]+'&_paged='+str(i))
    
    
URL
# Out:
# ['https://www.skinnytaste.com/recipe-index/?_course=drinks',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=2',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=3',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=4',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=5',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=6',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=7',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=8',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=9',
#  'https://www.skinnytaste.com/recipe-index/?_course=drinks&_paged=10']

# %% [markdown]
# ## Time- column

# %%
import numpy as np

# %%
time=[]
c=0
for i in main:
    time.append(i.text)
    c+=1
time.insert(1,np.nan)
time
# Out:
# ['5 mins',
#  nan,
#  '5 mins',
#  '5 mins',
#  '5 mins',
#  '10 mins',
#  '10 mins',
#  '3 hrs',
#  '5 mins',
#  '10 mins',
#  '10 mins',
#  '20 mins',
#  '5 mins',
#  '5 mins',
#  '5 mins',
#  '5 mins',
#  '15 mins',
#  '5 mins',
#  '5 mins',
#  '5 mins']

# %%
# a=re.findall('href=\"(.+)"><img',str(url[0]))
# a[0].split(' ')[0].split('"')[0]
# Out:
# 'https://www.skinnytaste.com/italian-sub-salad/'

# %%
#links
url=soup.find_all('div',class_='post-thumb-img-content post-thumb')
sub_url=[]
for i in url:
    a=re.findall('href=\"(.+)"><img',str(i))
    sub_url.append(a[0].split(' ')[0].split('"')[0])
sub_url
# Out:
# ['https://www.skinnytaste.com/carrot-banana-protein-smoothie/',
#  'https://www.skinnytaste.com/grapefruit-ginger-kombucha-mocktail/',
#  'https://www.skinnytaste.com/peanut-butter-jelly-smoothie/',
#  'https://www.skinnytaste.com/orange-moscow-mule-mocktail/',
#  'https://www.skinnytaste.com/zero-proof-jalapeno-paloma/',
#  'https://www.skinnytaste.com/virgin-bloody-mary/',
#  'https://www.skinnytaste.com/citrus-immunity-shot/',
#  'https://www.skinnytaste.com/boozy-watermelon-lime-granita/',
#  'https://www.skinnytaste.com/tropical-mango-blueberry-lassi/',
#  'https://www.skinnytaste.com/green-apple-lemon-cucumber-ginger-smoothie/',
#  'https://www.skinnytaste.com/basil-cucumber-gin-cooler/',
#  'https://www.skinnytaste.com/summer-mango-stone-fruit-smoothie/',
#  'https://www.skinnytaste.com/chia-watermelon-fresca/',
#  'https://www.skinnytaste.com/pina-banana-colada-smoothie/',
#  'https://www.skinnytaste.com/bali-banana-date-smoothie/',
#  'https://www.skinnytaste.com/superfood-pb-banana-and-cacao-green/',
#  'https://www.skinnytaste.com/roasted-strawberry-protein-smoothie-and/',
#  'https://www.skinnytaste.com/kale-banana-chia-hemp-superfood-smoothie/',
#  'https://www.skinnytaste.com/blueberry-kale-smoothie/',
#  'https://www.skinnytaste.com/blueberry-banana-oatmeal-smoothie/']

# %% [raw]
# # converting above urls(html) into string data
#
# for i in sub_url:
#     page=requests.get(i)
#     soup = BeautifulSoup(page.text)
#
# soup.text

# %% [raw]
# for i in sub_url:
#     page=requests.get(i)
#     soup = BeautifulSoup(page.text)
#     urls=[]
#     single=[]
#     for j in soup.find_all('a'):
#         single.append(j.text)
#         urls.append(single)
# urls

# %%
# urls=[]
# single=[]
# for j in soup.find_all('a'):
#     single.append(j.text)

#     urls.append(single)
# single
# urls[0]

# %%
link='https://www.skinnytaste.com/carrot-banana-protein-smoothie/'
page=requests.get(link)
soup = BeautifulSoup(page.text)
#soup

# %%
#title
soup.find_all('h1')[0].text
# Out:
# 'Carrot Banana Protein Smoothie'

# %%
#rating
soup.find_all('span',class_='wprm-recipe-rating-average')[0].text
# Out:
# '4.84'

# %%
#calories
c=soup.find_all('span',class_='recipe-meta-value value-calories')[0].text
c.split(' ')[1]
# Out:
# '294'

# %%
#protein
p=soup.find_all('span',class_='recipe-meta-value value-protein')[0].text
p.split(' ')[1]
# Out:
# '28.5'

# %%
#carbs
c=soup.find_all('span',class_='recipe-meta-value value-carbs')[0].text
c.split(' ')[1]
# Out:
# '34'

# %%
#fats
f=soup.find_all('span',class_='recipe-meta-value value-fat')[0].text
f.split(' ')[1]
# Out:
# '6.5'

# %%
#serving
s=soup.find_all('span',class_='wprm-recipe-nutrition-with-unit')
s[0].text
# Out:
# '1 smoothie'

# %%
#type
t=soup.find_all('span',class_= 'wprm-recipe-course wprm-block-text-normal')
t[0].text
# Out:
# 'Breakfast'

# %% [raw]
# #ingredients
# ii=soup.find_all('strong')
# re.findall('\>(\w+)',str(ii))

# %%
URL = ['https://www.skinnytaste.com/recipe-index/?_course=drinks']
Time = []
sub_url = []

for i in range(2, 4):
    URL.append(URL[0] + '&_paged=' + str(i))  # 10 pages

for j in URL:
    page = requests.get(j)
    soup = BeautifulSoup(page.text)
    print(page)

    for i in soup.find_all('article', class_='ast-archive-post'):
        time= i.find('span', class_='wprm-total-time')
        Time.append(time.text.strip() if time else np.nan)

    for l in soup.find_all('div', class_='post-thumb-img-content post-thumb'):
        a = re.findall('href=\"(.+)"><img', str(l))
        sub_url.append(a[0].split(' ')[0].split('"')[0])
        
print(len(Time))  
print(len(sub_url))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# 52
# 52

# %%
Title=[]
rating=[]
protein=[]
carbs=[]
calories=[]
fat=[]
serving=[]
type_of=[]
cholesterol=[]
sodium=[]
fiber=[]
sugar=[]
pre_time=[]
cook_time=[]
    
# Fetching sub-URLs inside the loop
for sub in sub_url:
    page1=requests.get(sub)
    soup1=BeautifulSoup(page1.text)
    
    Title.append(soup1.find('h1').text)
    
    r=soup1.find('span',class_='wprm-recipe-rating-average')
    rating.append(r.text if r else np.nan)
    
    cal=soup1.find('span',class_='recipe-meta-value value-calories')
    calories.append(cal.text.split(' ')[1] if cal else np.nan)
    
    p=soup1.find('span',class_='recipe-meta-value value-protein')
    protein.append(p.text.split(' ')[1] if p else np.nan)
    
    car=soup1.find('span',class_='recipe-meta-value value-carbs')
    carbs.append(car.text.split(' ')[1] if car else np.nan)
    
    f=soup1.find('span',class_='recipe-meta-value value-fat')
    fat.append(f.text.split(' ')[1] if f else np.nan)
    
    s=soup1.find('span',class_='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-serving_size wprm-block-text-normal')
    serving.append(s.text if s else np.nan)
    
    t=soup1.find('a',class_= 'tasty-link')
    type_of.append(t.text if t else np.nan)
    
    c=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-cholesterol')
    cholesterol.append(c.text.split(' ')[1] if c else np.nan)
    
    sod=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sodium')
    sodium.append(sod.text.split()[1] if sod else np.nan)
    
    f=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-fiber')
    fiber.append(f.text.split()[1] if f else np.nan)
    
    ss=soup1.find('span',class_='wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-sugar')
    sugar.append(ss.text.split()[1] if ss else np.nan)
    
    pt=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-prep_time wprm-recipe-prep_time-minutes')
    pre_time.append(pt.text.split()[0] if pt else np.nan)
    
    ct=soup1.find('span',class_='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes')
    cook_time.append(ct.text.split()[0] if ct else np.nan)
    
    
    
print(len(Title))
print(len(rating))
print(len(protein))
print(len(calories))
print(len(carbs))
print(len(fat))
print(len(serving))
print(len(type_of))
print(len(cholesterol))
print(len(sodium))
print(len(fiber))
print(len(sugar))
print(len(pre_time))
print(len(cook_time))
# Out:
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52

# %%
df4=pd.DataFrame({'Recipe_Name':Title,
                  "Type":type_of,
                  'Serving':serving,
                  "Protein":protein,
                  "Fat":fat,
                  "Carbs":carbs,
                  "Calories":calories,
                  'cholesterol':cholesterol,
                  'sodium':sodium,
                  'fiber':fiber,
                  'sugar':sugar,
                    'Prepare time':pre_time,
                  'cooking time': cook_time,
                  "Total_Time":Time,
                  "Ratings":rating,

                 
                 
                 })
df4.tail(3)
# Out:
#             Recipe_Name       Type Serving Protein  Fat Carbs Calories  \
# 49        Wine Spritzer     dinner       4     NaN  NaN   0.5       40
# 50        Mango Bellini  Breakfast       1     NaN  NaN   3.5     86.5
# 51  Skinny Cuban Mojito        NaN       1     NaN  NaN     5      102
#
#    cholesterol sodium fiber sugar Prepare time cooking time Total_Time Ratings
# 49         NaN   15.5   NaN   NaN            2          NaN     2 mins     NaN
# 50         NaN    NaN   NaN   1.5            3          NaN     3 mins     NaN
# 51         NaN   44.5   NaN   0.5            5          NaN     5 mins       3

# %%
#df4.to_csv("drinks.csv")

# %%
df4=pd.read_csv('drinks.csv',index_col=0)
df4
# Out:
#                                      Recipe_Name            Type  Serving  \
# 0                 Carrot Banana Protein Smoothie       breakfast      1.0
# 1            Grapefruit-Ginger Kombucha Mocktail             NaN      1.0
# 2               Peanut Butter and Jelly Smoothie           lunch      1.0
# 3                    Orange Moscow Mule Mocktail             NaN      1.0
# 4                     Zero-Proof Jalapeño Paloma             NaN      1.0
# 5                             Virgin Bloody Mary       appetizer      2.0
# 6                          Citrus Immunity Shots             NaN      1.0
# 7                  Boozy Watermelon Lime Granita         dessert      1.0
# 8                 Tropical Mango Blueberry Lassi       Breakfast      1.0
# 9     Green Apple Lemon Cucumber Ginger Smoothie       Breakfast      1.0
# 10                     Basil Cucumber Gin Cooler             NaN      1.0
# 11             Summer Mango Stone Fruit Smoothie       Breakfast      1.0
# 12                        Chia Watermelon Fresca             NaN      1.0
# 13                   Pina Banana Colada Smoothie       breakfast      1.0
# 14                     Bali Banana Date Smoothie       Breakfast      1.0
# 15  Superfood PB Banana and Cacao Green Smoothie       breakfast      1.0
# 16           Roasted Strawberry Protein Smoothie  cottage cheese      1.0
# 17   Kale, Banana, Chia, Hemp Superfood Smoothie       breakfast      1.0
# 18                       Blueberry Kale Smoothie       Breakfast      1.0
# 19             Blueberry Banana Oatmeal Smoothie       breakfast      1.0
# 20                        Watermelon Agua Fresca           lunch      1.0
# 21                        Matcha Green Tea Shots             NaN      2.0
# 22   Peach Banana Green Smoothie with Hemp Seeds       breakfast     16.0
# 23         Mango Banana Hemp Seed Green Smoothie       Breakfast     16.0
# 24            Tropical Papaya Batido Fruit Shake       breakfast      NaN
# 25                                Shamrock Shake         dessert      1.0
# 26                  Blueberry Banana PB Smoothie       Breakfast      1.0
# 27                   Skinny Frozen Hot Chocolate         Dessert      NaN
# 28                         Iced Green Tea Mojito             NaN      1.0
# 29                Very Berry Banana Fro Yo Shake         dessert      1.0
# 30                     Citrus Margarita Spritzer             NaN      1.0
# 31                      Celery Cilantro Cocktail             NaN      1.0
# 32                Skinny Green Tropical Smoothie       Breakfast      1.0
# 33                            Watermelon Martini             NaN      6.0
# 34                            Colombian Salpicón         dessert      1.0
# 35        Freshly Brewed Ice Tea with Fresh Mint             NaN      1.0
# 36                                      Horchata       Breakfast      1.0
# 37              Healthy Pumpkin Oatmeal Smoothie       breakfast      1.0
# 38                              Pumpkin Smoothie       breakfast      1.0
# 39                    Skinny Pumpkin Spice Latte       breakfast      1.0
# 40               Nojito (Virgin Mojito Mocktail)             NaN      1.0
# 41                              Skinny Margarita             NaN      1.0
# 42                          Mango Peach Smoothie       Breakfast      1.0
# 43                         Triple Berry Smoothie       breakfast      1.0
# 44                       Very Blueberry Smoothie       Breakfast      1.0
# 45                           Pomegranate Martini             NaN      4.0
# 46                           Skinny Eggnog Latte             NaN      NaN
# 47                                 Skinny Eggnog             NaN      1.0
# 48                                   Mango Lassi       Breakfast      1.0
# 49                                 Wine Spritzer          dinner      4.0
# 50                                 Mango Bellini       Breakfast      1.0
# 51                           Skinny Cuban Mojito             NaN      1.0
#
#     Protein   Fat  Carbs  Calories  cholesterol  sodium  fiber  sugar  \
# 0      28.5   6.5   34.0     294.0          NaN   290.5    7.0   17.5
# 1       0.5   0.5   15.0      66.0          NaN     1.5    0.5   12.5
# 2       6.0  11.0   29.0     222.0          NaN   216.0    8.0   19.0
# 3       1.0   NaN   27.0     104.0          NaN     NaN    3.0   20.5
# 4       0.5   NaN   17.0      66.0         16.0     1.0    NaN   14.0
# 5       1.0   0.5    7.0      33.0          NaN   295.0    1.5    4.5
# 6       0.5   NaN    6.0      25.0          NaN     0.5    1.0    4.0
# 7       0.5   0.5    NaN     109.0          NaN     2.0    0.5   11.5
# 8       8.0   6.0   34.5     215.0          2.5   221.0    5.0   24.5
# 9       2.0   0.5   30.5     110.0          NaN    20.0    6.5   18.0
# 10      NaN   NaN    7.0     137.0          NaN     7.0    NaN    5.0
# 11      2.0   0.5   35.0     122.0          NaN    20.0    4.0   24.0
# 12      5.0   6.0   22.0       6.0          NaN     5.0    6.0   15.0
# 13      2.0   6.0   27.0     160.0          NaN    95.0    4.0   18.0
# 14      5.0   1.0   39.0     195.0          6.0   136.0    3.0   31.0
# 15      6.0  11.5   21.0     188.0          NaN   210.0    6.5    8.5
# 16     16.0   3.4   33.0     213.0          5.5   360.0    7.5   27.0
# 17      8.0  10.0   30.0     220.0          NaN   158.0    8.0   14.0
# 18      9.0  12.0   51.0     312.0          NaN   241.0   10.0   31.0
# 19      3.0   2.0   38.0     180.0          NaN    52.5    4.0    8.0
# 20      1.5   1.0   16.5      73.0          NaN     4.5    1.0   15.0
# 21      1.0   2.0   10.0      55.0          NaN    76.0    1.0    9.0
# 22      7.0   8.0   31.0     205.0          NaN   170.0    6.0   20.0
# 23      5.0   6.0   27.0     173.5          NaN   171.0    4.5   15.5
# 24      3.0   1.0   49.0     205.0          NaN     6.0    4.0   35.5
# 25      7.0   6.0   23.0     169.5          2.0    90.5    2.5   19.0
# 26     13.0   4.0   48.5     261.0          NaN   212.4    8.0   26.5
# 27      7.0   1.0   20.0     111.0          3.0   166.0    1.0   18.0
# 28      0.5   0.5   11.0     110.0          NaN     4.0    0.5    9.0
# 29      5.6   2.1   48.0     211.7          NaN    90.6    5.7   26.3
# 30      0.5   0.5   12.0     137.0          NaN    13.5    0.5    9.0
# 31      0.2   NaN   19.9     135.0          NaN    15.8    1.2   15.8
# 32     10.2   7.7   30.2     228.0          NaN    70.5    3.9   19.4
# 33      1.0   0.5   11.5      90.5          NaN     2.5    0.5    7.5
# 34      0.5   0.5   14.0      52.0          NaN    10.0    2.0    7.0
# 35      NaN   NaN    0.8       3.0          NaN     0.1    NaN    0.2
# 36      3.0   0.5   31.5     138.0          1.0    30.5    1.5    2.5
# 37      3.8   0.9   21.5      95.0          1.3    30.0    2.6   11.0
# 38     10.6   0.5   40.0     185.5          1.2    66.8    2.6   10.2
# 39      6.6   0.4   20.8     115.6          3.7   100.0    0.7    4.7
# 40      0.5   0.1   15.2      58.5          NaN     NaN    0.9    NaN
# 41      0.2   NaN    3.3     185.5          NaN     1.0    0.2    1.0
# 42      2.3   0.3   26.0      99.7          NaN     NaN    5.0    NaN
# 43      9.4   0.3    9.7      75.9          NaN    40.3    2.7    6.0
# 44      3.4   NaN   16.2      80.5          NaN     NaN    3.0    NaN
# 45      0.4   NaN   13.1     117.0          NaN    11.5    NaN   13.0
# 46      NaN   NaN    NaN      73.0          NaN     NaN    NaN    NaN
# 47      5.3   2.5   15.3     106.7          NaN     NaN    NaN    NaN
# 48      9.2   0.3   26.7     138.7          1.5    22.5    1.3    NaN
# 49      NaN   NaN    0.5      40.0          NaN    15.5    NaN    NaN
# 50      NaN   NaN    3.5      86.5          NaN     NaN    NaN    1.5
# 51      NaN   NaN    5.0     102.0          NaN    44.5    NaN    0.5
#
#     Prepare time  cooking time     Total_Time  Ratings
# 0            5.0           0.0         5 mins     4.84
# 1            NaN           NaN            NaN     5.00
# 2            5.0           0.0         5 mins     5.00
# 3            5.0           0.0         5 mins     5.00
# 4            5.0           0.0         5 mins     5.00
# 5           10.0           0.0        10 mins     4.91
# 6           10.0           0.0        10 mins     4.67
# 7            NaN           0.0          3 hrs     5.00
# 8            5.0           0.0         5 mins     4.60
# 9           10.0           NaN        10 mins     4.29
# 10          10.0           0.0        10 mins     5.00
# 11          20.0           NaN        20 mins      NaN
# 12           5.0           NaN         5 mins     5.00
# 13           5.0           NaN         5 mins     4.75
# 14           1.0           4.0         5 mins     4.75
# 15           5.0           NaN         5 mins     4.34
# 16           3.0          12.0        15 mins     4.63
# 17           5.0           NaN         5 mins     4.75
# 18           5.0           NaN         5 mins      NaN
# 19           5.0           NaN         5 mins     4.00
# 20          10.0           NaN        10 mins     5.00
# 21           5.0           NaN         5 mins     5.00
# 22           NaN           NaN            NaN     4.34
# 23          10.0           NaN        10 mins      NaN
# 24          10.0           NaN        10 mins      NaN
# 25          10.0           0.0        10 mins     5.00
# 26           5.0           NaN         5 mins     4.89
# 27          10.0           NaN        10 mins      NaN
# 28          10.0           NaN        10 mins      NaN
# 29           5.0           NaN         5 mins      NaN
# 30           5.0           NaN         5 mins     5.00
# 31          10.0           NaN        10 mins      NaN
# 32           5.0           NaN         5 mins     4.50
# 33          15.0           NaN        15 mins      NaN
# 34          15.0           0.0        15 mins     5.00
# 35           NaN           NaN            NaN     3.00
# 36          10.0           0.0  8 hrs 10 mins     5.00
# 37          10.0           5.0        15 mins     5.00
# 38           5.0           0.0         5 mins     4.67
# 39          10.0           5.0        15 mins     5.00
# 40           NaN           NaN            NaN      NaN
# 41           5.0           NaN         5 mins      NaN
# 42           NaN           NaN            NaN     5.00
# 43           NaN           NaN            NaN      NaN
# 44           NaN           NaN            NaN      NaN
# 45           3.0           NaN         3 mins      NaN
# 46           NaN           NaN            NaN      NaN
# 47           NaN           NaN            NaN     4.50
# 48           5.0           NaN         5 mins     4.75
# 49           2.0           NaN         2 mins      NaN
# 50           3.0           NaN         3 mins      NaN
# 51           5.0           NaN         5 mins     3.00

# %%
df4['Type'].unique()
# Out:
# array(['breakfast', nan, 'lunch', 'appetizer', 'dessert', 'Breakfast',
#        'cottage cheese', 'Dessert', 'dinner'], dtype=object)

# %%
df4['Type']=df4["Type"].fillna(method="ffill")

# %%
#df4.to_csv("drinks.csv")
